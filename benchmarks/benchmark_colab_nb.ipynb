# %%
# !git clone https://github.com/maraxen/prxteinmpnn.git && cd prxteinmpnn && git fetch && git checkout md && uv pip install -e .
# Out:
# Cloning into 'prxteinmpnn'...
# remote: Enumerating objects: 7648, done.
# remote: Counting objects: 100% (659/659), done.
# remote: Compressing objects: 100% (574/574), done.
# remote: Total 7648 (delta 111), reused 153 (delta 73), pack-reused 6989 (from 2)
# Receiving objects: 100% (7648/7648), 158.93 MiB | 37.99 MiB/s, done.
# Resolving deltas: 100% (4820/4820), done.
# Branch 'md' set up to track remote branch 'md' from 'origin'.
# Switched to a new branch 'md'
# Using Python 3.12.12 environment at: /usr
# Resolved 108 packages in 1.23s
# Prepared 27 packages in 1.63s
# Uninstalled 1 package in 7ms
# Installed 27 packages in 55ms
#  + bibtexparser==1.4.3
#  + biotite==1.5.0
#  + biotraj==1.2.2
#  + dm-haiku==0.0.15
#  + e3nn-jax==0.20.8
#  + equinox==0.13.2
#  + gmmx==0.7
#  + grain==0.2.15
#  - huggingface-hub==0.36.0
#  + huggingface-hub==1.1.5
#  + hydride==1.2.3
#  + jax-md==0.2.27
#  + jaxtyping==0.3.3
#  + jmp==0.0.4
#  + jraph==0.0.6.dev0
#  + mdtraj==1.11.0
# ...

# %%
# !uv run python prxteinmpnn/scripts/benchmark_md/benchmark_conformation.py
# Out:
# Benchmarking Conformational Validity...
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/datasets/maraxen/eqx-ff/resolve/main/ff14SB.eqx "HTTP/1.1 401 Unauthorized"
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 553, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '401 Unauthorized' for url 'https://huggingface.co/datasets/maraxen/eqx-ff/resolve/main/ff14SB.eqx'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/prxteinmpnn/scripts/benchmark_md/benchmark_conformation.py", line 250, in <module>
#     run_benchmark()
# ...

# %%
# !uv run python prxteinmpnn/scripts/benchmark_md/benchmark_diversity.py

# %%
# !uv run python prxteinmpnn/scripts/benchmark_md/benchmark_noise.py

# %%
# !uv run python prxteinmpnn/scripts/benchmark_md/benchmark_recovery.py

# %%
# !uv run python prxteinmpnn/scripts/benchmark_md/benchmark_scaling.py

# %%
# !uv run python prxteinmpnn/scripts/benchmark_md/benchmark_scrmsd.py
# !uv run python prxteinmpnn/scripts/benchmark_md/stress_test_stability.py
